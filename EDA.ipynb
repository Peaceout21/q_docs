# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('hh.csv', encoding='cp1252')
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (13,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#              Ag_Num    Year_Month           Year          Month  \
# count  1.721770e+05  1.721770e+05  172177.000000  172177.000000
# mean   6.060089e+07  2.017171e+07    2017.100495       6.729191
# std    8.607902e+04  9.302115e+03       0.935725       3.326771
# min    6.000032e+07  2.016013e+07    2016.000000       1.000000
# 25%    6.056818e+07  2.016103e+07    2016.000000       4.000000
# 50%    6.061155e+07  2.017083e+07    2017.000000       6.000000
# 75%    6.065501e+07  2.018063e+07    2018.000000      10.000000
# max    6.069864e+07  2.019053e+07    2019.000000      12.000000
#
#        AG_Active_Ind        AG_API  AG_Policy_Count      AG_Tenure  \
# count  172177.000000  1.721770e+05    172177.000000  172177.000000
# mean        0.397916  7.818692e+06         0.570541       0.232305
# std         0.489469  1.513823e+07         1.011755       0.228922
# min         0.000000  0.000000e+00         0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (172177, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172177 entries, 0 to 172176
# Data columns (total 48 columns):
# Ag_Num                     172177 non-null int64
# Year_Month                 172177 non-null int64
# Year_Qtr                   172177 non-null object
# Year                       172177 non-null int64
# Month                      172177 non-null int64
# AG_Active_Ind              172177 non-null int64
# AG_API                     172177 non-null int64
# AG_Policy_Count            172177 non-null float64
# AG_Tenure                  172177 non-null float64
# AS_Level                   172177 non-null object
# AG_Unit                    172177 non-null object
# AG_Appointed_Year_Month    172177 non-null int64
# AG_Appointed_Date          172177 non-null object
# AG_Terminated_Date         10 non-null object
# AG_Sales_Zone              171984 non-null object
# AG_GA_Code                 172177 non-null object
# AG_Main_GA_Code            172177 non-null object
# ...

# %%
df.count()
# Out:
# Ag_Num                     172177
# Year_Month                 172177
# Year_Qtr                   172177
# Year                       172177
# Month                      172177
# AG_Active_Ind              172177
# AG_API                     172177
# AG_Policy_Count            172177
# AG_Tenure                  172177
# AS_Level                   172177
# AG_Unit                    172177
# AG_Appointed_Year_Month    172177
# AG_Appointed_Date          172177
# AG_Terminated_Date             10
# AG_Sales_Zone              171984
# AG_GA_Code                 172177
# AG_Main_GA_Code            172177
# AG_Main_GA                 172177
# AG_GA_dump                 172145
# AG_Province_Code           172177
# AG_Category                172177
# AG_Channel_Grp             172177
# AG_GAdump_segment          155921
# AG_MainGAdump              166689
# AG_Province_Name           172177
# AG_Region                  172177
# AG_SubRegion               172177
# ...

# %%
df.dtypes
# Out:
# Ag_Num                       int64
# Year_Month                   int64
# Year_Qtr                    object
# Year                         int64
# Month                        int64
# AG_Active_Ind                int64
# AG_API                       int64
# AG_Policy_Count            float64
# AG_Tenure                  float64
# AS_Level                    object
# AG_Unit                     object
# AG_Appointed_Year_Month      int64
# AG_Appointed_Date           object
# AG_Terminated_Date          object
# AG_Sales_Zone               object
# AG_GA_Code                  object
# AG_Main_GA_Code             object
# AG_Main_GA                  object
# AG_GA_dump                  object
# AG_Province_Code            object
# AG_Category                 object
# AG_Channel_Grp              object
# AG_GAdump_segment           object
# AG_MainGAdump               object
# AG_Province_Name            object
# AG_Region                   object
# AG_SubRegion                object
# ...

# %%
df.head()
# Out:
#      Ag_Num  Year_Month Year_Qtr  Year  Month  AG_Active_Ind    AG_API  \
# 0  60000323    20170131   2017Q1  2017      1              1  26444900
# 1  60001078    20170131   2017Q1  2017      1              1  41832000
# 2  60001116    20180331   2018Q1  2018      3              0         0
# 3  60001493    20161130   2016Q4  2016     11              1  13505900
# 4  60003175    20160630   2016Q2  2016      6              0         0
#
#    AG_Policy_Count  AG_Tenure AS_Level      ...      AG_Age_Join  \
# 0              1.0       0.37       AG      ...               43
# 1              3.0       0.40       AG      ...               44
# 2              0.0       0.03       AG      ...               51
# 3              1.0       0.07       AG      ...               45
# 4              0.0       0.03       AG      ...               39
#
#    AG_Age_Join_Grp AG_Occupation_Code               Ag_Occupation_Grp  \
# 0         04.41-50             2019.0  Sales (Insurance, Real estate)
# ...

# %%
list(df)
# Out:
# ['Ag_Num',
#  'Year_Month',
#  'Year_Qtr',
#  'Year',
#  'Month',
#  'AG_Active_Ind',
#  'AG_API',
#  'AG_Policy_Count',
#  'AG_Tenure',
#  'AS_Level',
#  'AG_Unit',
#  'AG_Appointed_Year_Month',
#  'AG_Appointed_Date',
#  'AG_Terminated_Date',
#  'AG_Sales_Zone',
#  'AG_GA_Code',
#  'AG_Main_GA_Code',
#  'AG_Main_GA',
#  'AG_GA_dump',
#  'AG_Province_Code',
#  'AG_Category',
#  'AG_Channel_Grp',
#  'AG_GAdump_segment',
#  'AG_MainGAdump',
#  'AG_Province_Name',
#  'AG_Region',
#  'AG_SubRegion',
#  'Ag_Prov_Latitude',
#  'Ag_Prov_Longitude',
#  'Ag_Region_Tier',
#  'Ag_SAS_SubRegion',
#  'Ag_Reg_Latitude',
#  'Ag_Reg_Longitude',
#  'CLNTNUM',
#  'AG_Gender_Grp',
#  'AG_Education',
#  'AG_Marital_Status_Grp',
#  'AG_DOB',
#  'AG_Age_Join',
#  'AG_Age_Join_Grp',
#  'AG_Occupation_Code',
#  'Ag_Occupation_Grp',
#  'AG_Cat_After6mth',
#  'PE_Converted',
#  'AG_APE_L6M',
#  'AG_Policy_L6M',
#  'Ag_Active_L3M',
#  'Ag_Active_L6M']

# %%
df.PE_Converted.value_counts()
# Out:
# Non-PE          149223
# PE Converted      6608
# Name: PE_Converted, dtype: int64

# %%
df1 = df[['AG_Active_Ind',
 'AG_API',
 'AG_Policy_Count',
 'AG_Tenure',
 'AS_Level',
 'AG_Unit',
 'AG_Sales_Zone',
 'AG_Province_Code',
 'AG_GAdump_segment',
 'AG_Gender_Grp',
 'AG_Education',
 'AG_Marital_Status_Grp',
 'AG_Age_Join',
 'AG_Age_Join_Grp',
 'Ag_Occupation_Grp',
 'AG_Cat_After6mth',
 'PE_Converted',
 'AG_APE_L6M',
 'AG_Policy_L6M',
 'Ag_Active_L3M',
 'Ag_Active_L6M']]

# %%
# Out:
#        AG_Active_Ind        AG_API  AG_Policy_Count      AG_Tenure  \
# count  172177.000000  1.721770e+05    172177.000000  172177.000000
# mean        0.397916  7.818692e+06         0.570541       0.232305
# std         0.489469  1.513823e+07         1.011755       0.228922
# min         0.000000  0.000000e+00         0.000000       0.000000
# 25%         0.000000  0.000000e+00         0.000000       0.000000
# 50%         0.000000  0.000000e+00         0.000000       0.200000
# 75%         1.000000  1.239460e+07         1.000000       0.400000
# max         1.000000  6.502617e+08        40.000000       1.000000
#
#          AG_Age_Join    AG_APE_L6M  AG_Policy_L6M  Ag_Active_L3M  \
# count  172177.000000  1.721770e+05  172177.000000  155831.000000
# mean       38.202123  1.818696e+07       1.294804       0.148937
# std        11.662101  5.411691e+07       3.446169       0.520271
# min        18.000000 -9.832770e+07      -1.000000       0.000000
# ...
